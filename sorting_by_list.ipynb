# %% [markdown]
# # Sorting by list of operators id
#  - use loc
#  - use list of id

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#  list of my shift ids
shift4ids = ['S00033','S00555','S00175','S00309','S00203','S00118','S00280','S00329','S00327','S00282','S00279','S00220','S00295','S00342','S00294','S00314','S00536','S00484','S00241','S00281','S00313','S00156','S00393']

# %%
#write address of file
df = pd.read_excel("vacat.xlsx",index_col= "Таб.")
df_shift4 = df.loc[shift4ids]
# df_shift4.to_excel("Shift4.xlsx")
df_shift4[df_shift4["Дней ежегодного отпуска"]>1]
# Out:
#                                       ФИО  х           Должность   DEP  \
# Таб.
# S00033     Антропов Алексей Александрович  1     Начальник смены  MOE1
# S00203         Болгова Оксана Анатольевна  1            Оператор  MOE1
# S00118           Васильев Иван Леонидович  1    Инженер-наладчик  MOE1
# S00327       Гладкова Екатерина Сергеевна  1            Оператор  MOE1
# S00282               Дайкер Ольга Юрьевна  1            Оператор  MOE1
# S00279     Дементьева Светлана Викторовна  1            Оператор  MOE1
# S00220     Жихарева Татьяна Александровна  1            Оператор  MOE1
# S00295         Кенжаева Замира Мансуровна  1            Оператор  MOE1
# S00342          Климов Вячеслав Вадимович  1            Оператор  MOE1
# S00294         Лабзина Елена Владимировна  1            Оператор  MOE1
# S00314         Литвин Михаил Владимирович  1            Оператор  MOE1
# S00536        Манахова Татьяна Витальевна  1            Оператор  MOE1
# ...

# %%
df_shift4.loc[[0,"S00393"]]
# Out:
#                               ФИО    х Должность   DEP  \
# Таб.
# 0                             NaN  NaN       NaN   NaN
# S00393  Чекалина Роза Анатольевна  1.0  Оператор  MOE1
#
#         Дней ежегодного отпуска  Дней доп.отпуска  Дней всего на 31.12.18  \
# Таб.
# 0                           NaN               NaN                     NaN
# S00393                      8.0              12.0                    20.0
#
#        комментарии
# Таб.
# 0              NaN
# S00393         NaN

# %%
df.iloc[:][[0,4]]
# Out:
#                                     ФИО  Дней ежегодного отпуска
# Таб.
# 1                                     2                        6
# S00378     Звонова Екатерина Алексеевна                       28
# S00351          Бурцев Сергей Сергеевич                       35
# S00037            Гнутов Сергей Юрьевич                       27
# S00219        Быкова Наталия Николаевна                       27
# S00032     Кулагина Екатерина Сергеевна                       23
# S00501        Рожков Мирослав Андреевич                       27
# S00133     Джураев Сергей Александрович                       25
# S00528     Кочеткова Евгения Михайловна                       23
# S00283          Попов Дмитрий Сергеевич                       19
# S00226  Бурмистрова Александра Павловна                       18
# S00489          Бэхле Людвиг Гвидо Якоб                       16
# S00039       Васильев Олег Владимирович                       20
# ...

# %%
df.iloc[0]
# Out:
# ФИО                        2
# х                          3
# Должность                  4
# DEP                        5
# Дней ежегодного отпуска    6
# Дней доп.отпуска           7
# Дней всего на 31.12.18     8
# комментарии                9
# Name: 1, dtype: object
